# %% [markdown]
# # Assignment 2 – Conversational AI System
#
# My chatbot is called **InfoBuddy**.
# It can tell the weather, search small facts, and solve math.
# It uses Gradio for the chat and ChromaDB for the search part.

# %%
# !python ../05_src/assignment_chat/app.py
